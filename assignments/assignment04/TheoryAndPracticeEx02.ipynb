# %% [markdown]
# # Theory and Practice of Visualization Exercise 2

# %% [markdown]
# ## Imports

# %%
from IPython.display import Image

# %% [markdown]
# ## Violations of graphical excellence and integrity

# %% [markdown]
# Find a data-focused visualization on one of the following websites that is a *negative* example of the principles that Tufte describes in *The Visual Display of Quantitative Information*.
#
# * [CNN](http://www.cnn.com/)
# * [Fox News](http://www.foxnews.com/)
# * [Time](http://time.com/)
#
# Upload the image for the visualization to this directory and display the image inline in this notebook.

# %%
Image(filename='141027150129-gender-gap-infographic-1024x576.jpg')

# %% [markdown]
# Describe in detail the ways in which the visualization violates graphical *integrity* and *excellence*:

# %% [markdown]
# While the shape is meant to represent the male/female sides of the issue, it makes the picture very unclear compared to a more visually clean bar graph or similar. The shaped sections also give the illusion of larger areas in different sections (ex. the woman's arm adds width). The male section of the graph is also superfluous, as it has a constant size for all countries. The graph is not explained in the article either, and the choice of countries is not related to its contents.
